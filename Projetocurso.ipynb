# %% [markdown]
# <a href="https://colab.research.google.com/github/ThallesLima3301/curso-pandas/blob/main/Projetocurso.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
vendas = pd.read_csv("data.csv")

# %%
vendas
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
print(vendas)
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
display(vendas.head(4))
##mostra as linhas
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
#
#    yr_renovated                    street       city  statezip country
# 0          2005      18810 Densmore Ave N  Shoreline  WA 98133     USA
# ...

# %%
print(vendas.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           4600 non-null   object
#  1   price          4600 non-null   float64
#  2   bedrooms       4600 non-null   float64
#  3   bathrooms      4600 non-null   float64
#  4   sqft_living    4600 non-null   int64
#  5   sqft_lot       4600 non-null   int64
#  6   floors         4600 non-null   float64
#  7   waterfront     4600 non-null   int64
#  8   view           4600 non-null   int64
#  9   condition      4600 non-null   int64
#  10  sqft_above     4600 non-null   int64
#  11  sqft_basement  4600 non-null   int64
#  12  yr_built       4600 non-null   int64
#  13  yr_renovated   4600 non-null   int64
#  14  street         4600 non-null   object
#  15  city           4600 non-null   object
#  16  statezip       4600 non-null   object
# ...

# %%
##head as primeiras tail as ultimas
dados = vendas[['city', 'street', 'bedrooms', 'country']].head(5)
dados = vendas[['city', 'street', 'bedrooms', 'country']].tail(5)
display(dados)
# Out:
#            city             street  bedrooms country
# 4595    Seattle     501 N 143rd St       3.0     USA
# 4596   Bellevue   14855 SE 10th Pl       3.0     USA
# 4597     Renton   759 Ilwaco Pl NE       3.0     USA
# 4598    Seattle  5148 S Creston St       4.0     USA
# 4599  Covington  18717 SE 258th St       3.0     USA

# %%
display(vendas.loc[4])
display(vendas.loc[10: 20], 'city')
# Out:
# date             2014-05-02 00:00:00
# price                       550000.0
# bedrooms                         4.0
# bathrooms                        2.5
# sqft_living                     1940
# sqft_lot                       10500
# floors                           1.0
# waterfront                         0
# view                               0
# condition                          4
# sqft_above                      1140
# sqft_basement                    800
# yr_built                        1976
# yr_renovated                    1992
# street             9105 170th Ave NE
# city                         Redmond
# statezip                    WA 98052
# country                          USA
# Name: 4, dtype: object
#                    date      price  bedrooms  bathrooms  sqft_living  \
# 10  2014-05-02 00:00:00   463000.0       3.0       1.75         1710
# 11  2014-05-02 00:00:00  1400000.0       4.0       2.50         2920
# ...

# %%
#exibir numero de imoveis com 2 quartos
quartos = vendas.loc[vendas['bedrooms'] == 2]
display(quartos)
# Out:
#                      date          price  bedrooms  bathrooms  sqft_living  \
# 5     2014-05-02 00:00:00  490000.000000       2.0       1.00          880
# 6     2014-05-02 00:00:00  335000.000000       2.0       2.00         1350
# 36    2014-05-02 00:00:00  440000.000000       2.0       1.00          800
# 42    2014-05-02 00:00:00  308500.000000       2.0       1.00          850
# 44    2014-05-02 00:00:00  235000.000000       2.0       1.00         1210
# ...                   ...            ...       ...        ...          ...
# 4570  2014-07-02 00:00:00  318000.000000       2.0       1.75         1530
# 4577  2014-07-03 00:00:00  287919.782609       2.0       1.00          870
# 4579  2014-07-06 00:00:00  454790.000000       2.0       1.75         1990
# 4582  2014-07-07 00:00:00  406062.500000       2.0       1.00         1290
# 4587  2014-07-08 00:00:00  229629.500000       2.0       1.00          770
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
display(vendas[['price', 'floors', 'country']].max())
# Out:
# price      26590000.0
# floors            3.5
# country           USA
# dtype: object

# %%
vendas['Ativo'] = True

display(vendas.head())
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
# ...

# %%
#Quero adicionar uma coluna de valor booleano no vendas
# chamada "Ativo" que, por padrão, vai ser True para 
# TODAS as linhas
vendas['Active'] = True
print(vendas.info())
display(vendas.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           4600 non-null   object
#  1   price          4600 non-null   float64
#  2   bedrooms       4600 non-null   float64
#  3   bathrooms      4600 non-null   float64
#  4   sqft_living    4600 non-null   int64
#  5   sqft_lot       4600 non-null   int64
#  6   floors         4600 non-null   float64
#  7   waterfront     4600 non-null   int64
#  8   view           4600 non-null   int64
#  9   condition      4600 non-null   int64
#  10  sqft_above     4600 non-null   int64
#  11  sqft_basement  4600 non-null   int64
#  12  yr_built       4600 non-null   int64
#  13  yr_renovated   4600 non-null   int64
#  14  street         4600 non-null   object
#  15  city           4600 non-null   object
#  16  statezip       4600 non-null   object
# ...

# %%
casa = vendas[['price', 'city', 'country','street', 'waterfront', 'bathrooms', 'bedrooms']]

# %%
display(casa)
# Out:
#              price       city country                    street  waterfront  \
# 0     3.130000e+05  Shoreline     USA      18810 Densmore Ave N           0
# 1     2.384000e+06    Seattle     USA           709 W Blaine St           0
# 2     3.420000e+05       Kent     USA  26206-26214 143rd Ave SE           0
# 3     4.200000e+05   Bellevue     USA           857 170th Pl NE           0
# 4     5.500000e+05    Redmond     USA         9105 170th Ave NE           0
# ...            ...        ...     ...                       ...         ...
# 4595  3.081667e+05    Seattle     USA            501 N 143rd St           0
# 4596  5.343333e+05   Bellevue     USA          14855 SE 10th Pl           0
# 4597  4.169042e+05     Renton     USA          759 Ilwaco Pl NE           0
# 4598  2.034000e+05    Seattle     USA         5148 S Creston St           0
# 4599  2.206000e+05  Covington     USA         18717 SE 258th St           0
#
#       bathrooms  bedrooms
# 0          1.50       3.0
# ...

# %%
casa['Obs'] = ["MELHOR Cidade pra morar" if city == 'Shoreline' else None for city in casa['city']]
display(casa.loc[casa['city'].isin(['Shoreline','Seattle', 'Bellevue', 'Renton', 'Covington']), ['city', 'Obs']])
# Out:
# <ipython-input-31-1e47277e02dc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   casa['Obs'] = ["MELHOR Cidade pra morar" if city == 'Shoreline' else None for city in casa['city']]
#            city                      Obs
# 0     Shoreline  MELHOR Cidade pra morar
# 1       Seattle                     None
# 3      Bellevue                     None
# 5       Seattle                     None
# 9       Seattle                     None
# ...         ...                      ...
# 4595    Seattle                     None
# 4596   Bellevue                     None
# 4597     Renton                     None
# 4598    Seattle                     None
# 4599  Covington                     None
#
# [2318 rows x 2 columns]

# %%
num = pd.read_csv("data.csv")
display(num)
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
colunas = ['country', 'city']
merge_df = vendas.merge(num, how="inner", on=colunas)
display(merge_df)
print(merge_df.info())
# Out:
#                       date_x   price_x  bedrooms_x  bathrooms_x  \
# 0        2014-05-02 00:00:00  313000.0         3.0         1.50
# 1        2014-05-02 00:00:00  313000.0         3.0         1.50
# 2        2014-05-02 00:00:00  313000.0         3.0         1.50
# 3        2014-05-02 00:00:00  313000.0         3.0         1.50
# 4        2014-05-02 00:00:00  313000.0         3.0         1.50
# ...                      ...       ...         ...          ...
# 2962357  2014-06-05 00:00:00  685000.0         3.0         2.75
# 2962358  2014-06-06 00:00:00  320000.0         3.0         1.75
# 2962359  2014-06-06 00:00:00  320000.0         3.0         1.75
# 2962360  2014-07-08 00:00:00  250000.0         3.0         1.75
# 2962361  2014-07-08 00:00:00  250000.0         3.0         1.75
#
#          sqft_living_x  sqft_lot_x  floors_x  waterfront_x  view_x  \
# 0                 1340        7912       1.5             0       0
# ...
